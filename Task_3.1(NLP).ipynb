# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Winston')
# Out:
# {'last_letter': 'n'}

# %%
from nltk.corpus import names

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + 
                 [(name, 'female') for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'v'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': ' '}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'g'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'v'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'v'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'c'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'g'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'b'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'x'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'w'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'f'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'p'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'm'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'z'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'w'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'x'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ...]

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Vishakh'))
# Out:
# 'female'

# %%
classifier.classify(gender_features('Raunit'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Veer'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.762
